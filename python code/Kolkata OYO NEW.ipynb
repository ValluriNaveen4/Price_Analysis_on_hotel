# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import warnings
warnings.filterwarnings('ignore')

# %%
hotel=[]
price=[]
location=[]
km=[]
rating=[]
city=[]
discount=[]
Star_rating=[]
Ratedby=[]
Overall=[]
original_price=[]
for i in range(1,7):
    url=f"https://www.oyorooms.com/hotels-in-kolkata/?page={i}"
    link=requests.get(url)
    a=requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
    content=a.text
    soup=BeautifulSoup(content)
    
    container=soup.find_all("div",class_="hotelCardListing__descriptionWrapper")
    
#     for i in container:
#         print(i.text)
    for i in container:
        a=i.find("a",class_="c-nn640c u-width100")
        text=a.text
        hotel.append(text)
    for i in container:
        b=i.find("div",class_="d-body-lg listingHotelDescription__hotelAddress")
        text=b.text
        #print(text)
        regex=re.findall("(.*),",text)
        
        if regex:
            location.append(regex[0])
        else:
            location.append(np.nan)
        
        regex1=re.findall(",\s(Kolkata).",text)
        #print(regex1)
        if regex1:
            city.append(regex1[0])
        else:
            city.append("Kolkata")
        
        regex2=re.findall("(\d\.\d\skm)",text)
        #print(regex1)
        if regex2:
            km.append(regex2[0])
        else:
            km.append(np.nan)
    for i in container:
        b=i.find('div',class_='hotelRating')
        text=b.text
        regex=re.findall("\d\.\d",text)
        if regex:
            Star_rating.append(regex[0])
        else:
            Star_rating.append(np.nan)
        regex2=re.findall("\((\d+\s)",text)
        if regex2:
            Ratedby.append(regex2[0])
        else:
            Ratedby.append(np.nan)
        regex3=re.findall('.(\w+.\w+$)',text)
        if regex3:
            Overall.append(regex3[0])
        else:
            Overall.append(np.nan)
    for i in container:
        b=i.find('span',class_="listingPrice__finalPrice")
        text=b.text
        regex=re.findall("\d+",text)
        if regex:
            price.append(regex[0])
        else:
            price.append(np.nan)
    for i in container:
        b=i.find("span",class_="listingPrice__slashedPrice d-body-lg")
        text=b.text
        regex=re.findall("\d+",text)
        if regex:
            original_price.append(regex[0])
        else:
            original_price.append(np.nan)
    for i in container:
        b=i.find('span',class_="listingPrice__percentage")
        text=b.text
        regex=re.findall("\d+",text)
        if regex:
            discount.append(regex[0])
        else:
            discount.append(np.nan)

# %%
oyo_kolkata=pd.DataFrame({'Hotel_Name':hotel,'location':location,'City':city,"Star_rating":Star_rating,"Ratedby":Ratedby,"Ratingsummary":Overall,"Original_price_in(₹)":original_price,"Discount_in(%)":discount,"Final_price_in(₹)":price})

# %%
oyo_kolkata
# Out:
#                                             Hotel_Name  \
# 0     SPOT ON Dalhousie Guest House Near Howrah Bridge
# 1    OYO White Palace Hotel & Resort New Alipore Ne...
# 2                                Flagship Royal Palace
# 3             Flagship Royal Plaza Near Acropolis Mall
# 4    Collection O Hotel Green Leaf Near Acropolis Mall
# ..                                                 ...
# 115                      OYO Flagship 70403 Chinar Inn
# 116  Flagship Relax View Dumdum Park Near City Cent...
# 117  OYO Townhouse 424 Beck Bagan Ballygunge Near B...
# 118  Townhouse OAK Hotel Tahoura International Near...
# 119  Flagship Amaris Stay Hub VIP Bazar Near Scienc...
#
#                                               location     City Star_rating  \
# 0                                           Stand Road  Kolkata         4.5
# 1                       Opposite New Alipore Residency  Kolkata         4.0
# ...

# %%
oyo_kolkata.isnull().sum()
# Out:
# Hotel_Name              0
# location                7
# City                    0
# Star_rating             4
# Ratedby                 4
# Ratingsummary           4
# Original_price_in(₹)    0
# Discount_in(%)          0
# Final_price_in(₹)       0
# dtype: int64

# %%
oyo_kolkata["Star_rating"]=oyo_kolkata["Star_rating"].astype(float)

# %%
oyo_kolkata["Star_rating"].mean()
# Out:
# 3.9094827586206886

# %%
oyo_kolkata["Star_rating"]=oyo_kolkata["Star_rating"].fillna(3.8)

# %%
oyo_kolkata["Ratedby"]=oyo_kolkata["Ratedby"].astype(float)

# %%
oyo_kolkata["Ratedby"]=oyo_kolkata["Ratedby"].fillna(oyo_kolkata["Ratedby"].mean())

# %%
oyo_kolkata["Ratedby"]=oyo_kolkata["Ratedby"].astype(int)

# %%
oyo_kolkata["Final_price_in(₹)"]=oyo_kolkata["Final_price_in(₹)"].astype(int)

# %%
oyo_kolkata["Original_price_in(₹)"]=oyo_kolkata["Original_price_in(₹)"].astype(int)

# %%
oyo_kolkata["Discount_in(%)"]=oyo_kolkata["Discount_in(%)"].astype(int)

# %%
#Filling the missing values using Mode

x=oyo_kolkata.Ratingsummary.mode()[0]
oyo_kolkata.Ratingsummary.fillna(x,inplace=True)

# %%
oyo_kolkata.isnull().sum()
# Out:
# Hotel_Name              0
# location                7
# City                    0
# Star_rating             0
# Ratedby                 0
# Ratingsummary           0
# Original_price_in(₹)    0
# Discount_in(%)          0
# Final_price_in(₹)       0
# dtype: int64

# %%
oyo_kolkata.dropna(inplace=True)

# %%
oyo_kolkata.isnull().sum()
# Out:
# Hotel_Name              0
# location                0
# City                    0
# Star_rating             0
# Ratedby                 0
# Ratingsummary           0
# Original_price_in(₹)    0
# Discount_in(%)          0
# Final_price_in(₹)       0
# dtype: int64

# %%
oyo_kolkata
# Out:
#                                             Hotel_Name  \
# 0     SPOT ON Dalhousie Guest House Near Howrah Bridge
# 1    OYO White Palace Hotel & Resort New Alipore Ne...
# 2                                Flagship Royal Palace
# 3             Flagship Royal Plaza Near Acropolis Mall
# 4    Collection O Hotel Green Leaf Near Acropolis Mall
# ..                                                 ...
# 115                      OYO Flagship 70403 Chinar Inn
# 116  Flagship Relax View Dumdum Park Near City Cent...
# 117  OYO Townhouse 424 Beck Bagan Ballygunge Near B...
# 118  Townhouse OAK Hotel Tahoura International Near...
# 119  Flagship Amaris Stay Hub VIP Bazar Near Scienc...
#
#                                               location     City  Star_rating  \
# 0                                           Stand Road  Kolkata          4.5
# 1                       Opposite New Alipore Residency  Kolkata          4.0
# ...

# %%
oyo_kolkata.to_csv("oyokolkata10")
